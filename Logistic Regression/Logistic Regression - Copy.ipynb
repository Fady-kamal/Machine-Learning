# %% [markdown]
# # Exploration of the dataset
# This Data set is used to know  which of the users purchased/not purchased a particular product
#
# # Description
# <br>
# <dl>
#   <dt>User ID</dt>
#     <dd>It stands for <strong>User Identification</strong>, and it's a bunch of numbers enables system to identify and distinguish between the users who access or use it.</dd>
#   <dt>Gender</dt>
#     <dd>The fact of being male or female</dd>
#   <dt>Age</dt>
#     <dd>The age of the user</dd>
#   <dt>Estimated Salary</dt>
#     <dd>The approximate salary of the user</dd>
#   <dt>Purchased</dt>
#     <dd>It's a logical value to know if the user  purchased/not purchased a particular product</dd>
#     <dd> <strong>1: </strong> means the user purchased the product</dd>
#     <dd> <strong>0: </strong> means the user didn't purchase the product</dd>
#
# </dl>

# %%
#import the important libraries
import numpy as np 

import pandas as pd 

import seaborn as sns

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#import the data
train_df = pd.read_csv('Social_Network_Ads.csv')

# %%
#Explore the data
train_df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
#Explore the shape of the training dataset
train_df.shape
# Out:
# (400, 5)

# %% [markdown]
# # Preparing The Dataset for Logistic Regression Model

# %%
#split the dataset into features and labels 
x_train = train_df[train_df.columns[train_df.columns != 'Purchased'] & train_df.columns[train_df.columns != 'User ID'] &train_df.columns[train_df.columns != 'Gender']]
y_train = train_df[train_df.columns[train_df.columns == 'Purchased']]

#lets print the shape of the features and labels
print("The Shape of x_train: ",x_train.shape)
print("The Shape of y_train: ",y_train.shape)
# Out:
# The Shape of x_train:  (400, 2)
# The Shape of y_train:  (400, 1)

# %%
#Explore the features after removing some of them
x_train
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %% [markdown]
# ## Note:
#
# We remove <strong> "User ID" Feature </strong> because it doesn't affect the output so, we don't need it.
# <br>
#
# Also, we remove <strong> "Gender" Feature </strong> because we don't explain One-Hot-Encoding in this lab

# %%
#Convert the fearues into numpy array so we can feed them to our model
X_without_Xo = x_train.values

# %%
#Define the number of the training examples
m = X_without_Xo.shape[0]

print("The Number of Training examples: {0}".format(m))
# Out:
# The Number of Training examples: 400

# %% [markdown]
# # Define Some Helper Functions
# <br>
# <dl>
#   <dt>sigmod()</dt>
#   <dd>For applying sigmoid function  on our design matrix, X, to be our hypothsis for non-linear problems</dd>
#     <dt>featureNormalize()</dt>
#   <dd>For feature scalling to make the gradient descent converge much more quickly</dd>
#   <dt>computeCost()</dt>
#   <dd>For Computing cross entropy cost function for Logistic Regression model </dd>
#   <dt>gradientDescent()</dt>
#   <dd>For Updating the parameters</dd>
#   <dt>pred()</dt>
#   <dd>For making predictions</dd>
# </dl>
#
#
# <br>
#
# ### The Formula of Sigmoid Function in Vectorized Form:
# \begin{equation}
#  sigmoid(z) = \frac{1}{1 + e^{-\theta^{T}X}} = \frac{1}{1 + e^{-X\theta}}
# \end{equation}

# %%
 def sigmoid(X,theta):
        '''
        Usage:
          #sigmoid --> Computes sigmoid of z = X𝜃 element-wise.
  
        Arguments:
          #X --> The Design Matrix
          #theta --> The Parameters which need to update
    
        Returns:
          #returns ---> The Value of sigmoid of z
        '''
        #Compute  Our linear-hypothesis function 
        z = np.matmul(X,theta)
        
        #computes the sigmoid of z
        g = np.divide(1, (np.add(1, np.exp(-z))))
        
        return g

# %%
def featureNormalize(X):
    '''
    Usage:
      #featureNormalize--> used for normalizing features
  
    Arguments:
      #X --> The Design Matrix
    
    Returns:
      #The Normalized Matrix
      
    Notes:
      #X is a matrix where each column is a feature and each row is an example
      #So, you need to perform the normalization separately for each feature
    '''
    
    #Preallocating some variables to be used later 
    X_norm = np.copy(X)
    mu = np.zeros((1, X.shape[1]))
    sigma = np.zeros((1,X.shape[1]))

    #compute the mean of the feature and subtract it from the dataset, storing the mean value in mu
    #Next, compute the standard deviation of each feature, storing the standard deviation in sigma.
    for i in range(X.shape[1]):
        mu[0, i] = mu[0, i] + np.mean(X_norm[:, i])
        sigma[0, i] = sigma[0, i] + np.std(X_norm[:, i])
        
    #Finally, compute the standard deviation of each feature and divide each feature by it's standard deviation, storing the result in x_norm
    for i in range(X.shape[1]):
        X_norm[:, i] = np.divide(np.subtract(X_norm[:, i], mu[0, i]), sigma[0, i])
        
    return X_norm, mu, sigma

# %% [markdown]
# ### The Formula of Cross Entropy Cost Functin:
#
# \begin{equation}
#   CE = \sum_{i=1}^{m} {Loss(y_{pred},y)} =\frac{1}{m}\sum_{i=1}^{m} {(y^{(i)})(-\log(y_{pred}^{(i)})) - (l-y^{(i)})(\log(1-y_{pred}^{(i)}))}
# \end{equation}
#
# ### Note:
# The type of product in this formula is <strong> element-wise multiplication</strong>

# %%
def computeCost(X,y,theta):
    '''
    Usage:
      #computCost --> computes the cost for logistic regression
  
    
    Arguments:
      #X --> The Design Matrix
      #y --> The Ground Truth
      #theta --> The Parameters which need to update
    
    Returns:
      #The cost value
    '''
    
    #Compute  Our non-linear hypothesis function 
    h = sigmoid(X,theta)
    
    #Compute the losses
    losses = np.subtract(np.multiply(-y,np.log(h)), np.multiply((1-y),np.log(1-h)))
     
    #Compute the Cross Entropy Cost function
    J = (1/m)*(np.sum(losses))
    
    return J

# %% [markdown]
# ## Note:
# The terms cost and loss functions almost refer to the same meaning. But, loss function mainly applies for a single sample in the training set as compared to the cost function which deals with a penalty for a number of training sets
#
# <strong>In short, </strong> The cost Fucntion compute the error over all the trianing set while, the loss function compute the error over a single sample in the training set

# %% [markdown]
# <br>
#
# ### The Formula of The Gradient is:
#
# \begin{equation}
# \frac{\partial J}{\partial \theta_{j}} = \frac{1}{m} \big(\sum_{i=1}^{m} { (y_{pred}^{(i)} - y^{(i)}) x^{(i)}_{j} \big)}
# \end{equation}
#
#
# The type of product in this formula is <strong> element-wise multiplication</strong>

# %%
def gradientDescent(X,y,theta,alpha,num_iters):
    '''
    Usage:
      #gradientDescent --> computes the gradient descent for linear regression
  
    
    Arguments:
      #X --> The Design Matrix
      #y --> The Ground Truth
      #theta --> The Parameters which need to update
      #alpha --> is the learning rate which indicates the learning step or how far we go down 
      #num_iters--> is the number of iterations needed to go to the global optima
    
    Returns:
      #The updated parameters,theta 
      #cost_history: which is list containing the the values of the cost function, J, for every iteration
    '''
    #Define the cost history as empty list
    cost_history = []
    
    #Preallocating gradient for faster computaions 
    #The size of gradient equals:(numfeatures (includingx_0),)
    dtheta = np.zeros((X.shape[1],))

    
    #Keep until Convergence
    for i in range(num_iters+1):
        
        #Compute sigmoid of X𝜃 element-wise with the parameters, theta, that we intialize
        h = sigmoid(X,theta)
        
        #dtheta is the partial derivates of cost function with respect to the parameters, theta
        dtheta = (1/m)*(np.matmul(X.T, (np.subtract(h, y))))
        
        #Update theta
        theta = theta - alpha*dtheta
        
        #While debugging, it can be useful to print out the values of the cost function (computeCost) 
        cost = computeCost(X,y,theta)
        
        #Append the value of the cost at a specific value for theta to cost_history
        cost_history.append(cost)
        
        #print the cost function for every itration to track its new value step-by-step
        print("Reached iteration: {0}, the cost = {1}".format(i, cost))
    
    print("\n\nParameters have been trained!") 
    
    return theta, cost_history

# %%
def pred(input_pred,theta):
    '''
    Usage:
      #pred --> used to predict the output of the input
      
    Arguments:
      #input_pred --> the input you want to predict its output 
      #theta --> the updated param
    
    Returns:
      #The predicted output
    '''
    #First, Normalize the input 
    #input_pred,_,_ = featureNormalize(input_pred)
    
    #Compute the prediction
    prediction = sigmoid(input_pred,theta)
    
    print("The output: {0}\n".format(prediction))
    
    #check if the prediction is greater than 0.5 , the user purchased the product 
    if (np.greater(prediction,0.5) == True):
        print("Result: The user purchased the product ")
        
    #if not, the user didn't purchase the product
    else:
        print("Result: The user didn't purchase the product ")
        
    return prediction

# %% [markdown]
# # Training The Model

# %%
#First, we normalize the features
#_,_ indicate that we don't want to return mu and sigma so the function just return the normalize features
X_normalized,_,_ = featureNormalize(X_without_Xo)

# %%
#Then We concatenate x_0 with X_normalized 

#Create array of ones , which representes the x_0, to combine it with the rest of the features
ones = np.ones((400,1))

#Combining, so the shape of  the features will be (400,5) 
X = np.concatenate((ones, X_normalized), axis = 1)

#(Optional) --> lets reduce the rank of the output, y, to be (400,) instead of (400,1) 
#And, convert it to numpy array  of size (400,)
y = y_train.values.reshape(400,)

# %%
#Print the shape of the final features matrix  and the labels
print("The Shape of x: ",X.shape)
print("The Shape of y: ",y.shape)
# Out:
# The Shape of x:  (400, 3)
# The Shape of y:  (400,)

# %%
#Train the model
theta, cost_history =  gradientDescent(X,y,theta=np.array([0,0,0]),alpha = 0.001,num_iters = 2000)
# Out:
# Reached iteration: 0, the cost = 0.6930879513485616
# Reached iteration: 1, the cost = 0.6930287324644099
# Reached iteration: 2, the cost = 0.6929695239074896
# Reached iteration: 3, the cost = 0.6929103256777995
# Reached iteration: 4, the cost = 0.6928511377753381
# Reached iteration: 5, the cost = 0.6927919602001031
# Reached iteration: 6, the cost = 0.6927327929520922
# Reached iteration: 7, the cost = 0.6926736360313018
# Reached iteration: 8, the cost = 0.6926144894377285
# Reached iteration: 9, the cost = 0.6925553531713683
# Reached iteration: 10, the cost = 0.692496227232217
# Reached iteration: 11, the cost = 0.6924371116202691
# Reached iteration: 12, the cost = 0.6923780063355196
# Reached iteration: 13, the cost = 0.692318911377962
# Reached iteration: 14, the cost = 0.6922598267475902
# Reached iteration: 15, the cost = 0.6922007524443976
# Reached iteration: 16, the cost = 0.6921416884683764
# Reached iteration: 17, the cost = 0.6920826348195189
# Reached iteration: 18, the cost = 0.692023591497817
# Reached iteration: 19, the cost = 0.6919645585032613
# Reached iteration: 20, the cost = 0.6919055358358434
# Reached iteration: 21, the cost = 0.6918465234955526
# Reached iteration: 22, the cost = 0.6917875214823795
# Reached iteration: 23, the cost = 0.691728529796313
# Reached iteration: 24, the cost = 0.6916695484373421
# Reached iteration: 25, the cost = 0.6916105774054548
# Reached iteration: 26, the cost = 0.6915516167006395
# Reached iteration: 27, the cost = 0.6914926663228833
# Reached iteration: 28, the cost = 0.6914337262721734
# Reached iteration: 29, the cost = 0.6913747965484955
# Reached iteration: 30, the cost = 0.6913158771518366
# Reached iteration: 31, the cost = 0.6912569680821815
# Reached iteration: 32, the cost = 0.6911980693395157
# Reached iteration: 33, the cost = 0.6911391809238232
# Reached iteration: 34, the cost = 0.6910803028350887
# Reached iteration: 35, the cost = 0.6910214350732953
# Reached iteration: 36, the cost = 0.6909625776384265
# Reached iteration: 37, the cost = 0.6909037305304646
# Reached iteration: 38, the cost = 0.690844893749392
# Reached iteration: 39, the cost = 0.6907860672951904
# Reached iteration: 40, the cost = 0.690727251167841
# Reached iteration: 41, the cost = 0.6906684453673245
# Reached iteration: 42, the cost = 0.6906096498936214
# Reached iteration: 43, the cost = 0.690550864746711
# Reached iteration: 44, the cost = 0.6904920899265733
# Reached iteration: 45, the cost = 0.6904333254331867
# Reached iteration: 46, the cost = 0.6903745712665297
# Reached iteration: 47, the cost = 0.6903158274265804
# Reached iteration: 48, the cost = 0.6902570939133156
# Reached iteration: 49, the cost = 0.690198370726713
# Reached iteration: 50, the cost = 0.6901396578667484
# Reached iteration: 51, the cost = 0.6900809553333985
# Reached iteration: 52, the cost = 0.6900222631266384
# Reached iteration: 53, the cost = 0.6899635812464432
# Reached iteration: 54, the cost = 0.6899049096927877
# Reached iteration: 55, the cost = 0.6898462484656455
# Reached iteration: 56, the cost = 0.6897875975649908
# Reached iteration: 57, the cost = 0.6897289569907963
# Reached iteration: 58, the cost = 0.6896703267430349
# Reached iteration: 59, the cost = 0.6896117068216787
# Reached iteration: 60, the cost = 0.6895530972266998
# Reached iteration: 61, the cost = 0.6894944979580688
# Reached iteration: 62, the cost = 0.689435909015757
# Reached iteration: 63, the cost = 0.6893773303997348
# Reached iteration: 64, the cost = 0.6893187621099715
# Reached iteration: 65, the cost = 0.6892602041464366
# Reached iteration: 66, the cost = 0.6892016565090993
# Reached iteration: 67, the cost = 0.6891431191979277
# Reached iteration: 68, the cost = 0.6890845922128896
# Reached iteration: 69, the cost = 0.6890260755539529
# Reached iteration: 70, the cost = 0.6889675692210844
# Reached iteration: 71, the cost = 0.6889090732142507
# Reached iteration: 72, the cost = 0.6888505875334172
# Reached iteration: 73, the cost = 0.6887921121785502
# Reached iteration: 74, the cost = 0.6887336471496146
# Reached iteration: 75, the cost = 0.6886751924465749
# Reached iteration: 76, the cost = 0.6886167480693951
# Reached iteration: 77, the cost = 0.688558314018039
# Reached iteration: 78, the cost = 0.6884998902924698
# Reached iteration: 79, the cost = 0.6884414768926501
# Reached iteration: 80, the cost = 0.6883830738185424
# Reached iteration: 81, the cost = 0.6883246810701081
# Reached iteration: 82, the cost = 0.6882662986473085
# Reached iteration: 83, the cost = 0.6882079265501047
# Reached iteration: 84, the cost = 0.6881495647784569
# Reached iteration: 85, the cost = 0.6880912133323247
# Reached iteration: 86, the cost = 0.6880328722116679
# Reached iteration: 87, the cost = 0.687974541416445
# Reached iteration: 88, the cost = 0.6879162209466148
# Reached iteration: 89, the cost = 0.687857910802135
# Reached iteration: 90, the cost = 0.6877996109829633
# Reached iteration: 91, the cost = 0.6877413214890564
# Reached iteration: 92, the cost = 0.6876830423203711
# Reached iteration: 93, the cost = 0.6876247734768633
# Reached iteration: 94, the cost = 0.6875665149584885
# Reached iteration: 95, the cost = 0.6875082667652024
# Reached iteration: 96, the cost = 0.6874500288969587
# Reached iteration: 97, the cost = 0.6873918013537121
# Reached iteration: 98, the cost = 0.6873335841354163
# Reached iteration: 99, the cost = 0.6872753772420245
# Reached iteration: 100, the cost = 0.6872171806734891
# Reached iteration: 101, the cost = 0.6871589944297628
# Reached iteration: 102, the cost = 0.6871008185107972
# Reached iteration: 103, the cost = 0.6870426529165434
# Reached iteration: 104, the cost = 0.6869844976469527
# Reached iteration: 105, the cost = 0.6869263527019749
# Reached iteration: 106, the cost = 0.6868682180815604
# Reached iteration: 107, the cost = 0.6868100937856585
# Reached iteration: 108, the cost = 0.6867519798142178
# Reached iteration: 109, the cost = 0.6866938761671869
# Reached iteration: 110, the cost = 0.6866357828445143
# Reached iteration: 111, the cost = 0.6865776998461468
# Reached iteration: 112, the cost = 0.6865196271720316
# Reached iteration: 113, the cost = 0.6864615648221155
# Reached iteration: 114, the cost = 0.6864035127963445
# Reached iteration: 115, the cost = 0.6863454710946642
# Reached iteration: 116, the cost = 0.6862874397170197
# Reached iteration: 117, the cost = 0.6862294186633556
# Reached iteration: 118, the cost = 0.6861714079336164
# Reached iteration: 119, the cost = 0.6861134075277455
# Reached iteration: 120, the cost = 0.6860554174456863
# Reached iteration: 121, the cost = 0.6859974376873814
# Reached iteration: 122, the cost = 0.6859394682527732
# Reached iteration: 123, the cost = 0.6858815091418038
# Reached iteration: 124, the cost = 0.6858235603544138
# Reached iteration: 125, the cost = 0.685765621890545
# Reached iteration: 126, the cost = 0.685707693750137
# Reached iteration: 127, the cost = 0.6856497759331301
# Reached iteration: 128, the cost = 0.6855918684394638
# Reached iteration: 129, the cost = 0.685533971269077
# Reached iteration: 130, the cost = 0.6854760844219083
# Reached iteration: 131, the cost = 0.6854182078978954
# Reached iteration: 132, the cost = 0.6853603416969761
# Reached iteration: 133, the cost = 0.6853024858190877
# Reached iteration: 134, the cost = 0.6852446402641661
# Reached iteration: 135, the cost = 0.6851868050321482
# Reached iteration: 136, the cost = 0.6851289801229692
# Reached iteration: 137, the cost = 0.6850711655365643
# Reached iteration: 138, the cost = 0.6850133612728685
# Reached iteration: 139, the cost = 0.6849555673318156
# Reached iteration: 140, the cost = 0.6848977837133399
# Reached iteration: 141, the cost = 0.684840010417374
# Reached iteration: 142, the cost = 0.6847822474438513
# Reached iteration: 143, the cost = 0.6847244947927041
# Reached iteration: 144, the cost = 0.6846667524638638
# Reached iteration: 145, the cost = 0.6846090204572621
# Reached iteration: 146, the cost = 0.6845512987728298
# Reached iteration: 147, the cost = 0.6844935874104978
# Reached iteration: 148, the cost = 0.6844358863701954
# Reached iteration: 149, the cost = 0.6843781956518525
# Reached iteration: 150, the cost = 0.6843205152553978
# Reached iteration: 151, the cost = 0.6842628451807602
# Reached iteration: 152, the cost = 0.6842051854278677
# Reached iteration: 153, the cost = 0.6841475359966478
# Reached iteration: 154, the cost = 0.6840898968870275
# Reached iteration: 155, the cost = 0.6840322680989337
# Reached iteration: 156, the cost = 0.6839746496322923
# Reached iteration: 157, the cost = 0.6839170414870293
# Reached iteration: 158, the cost = 0.6838594436630697
# Reached iteration: 159, the cost = 0.6838018561603383
# Reached iteration: 160, the cost = 0.6837442789787593
# Reached iteration: 161, the cost = 0.6836867121182572
# Reached iteration: 162, the cost = 0.6836291555787543
# Reached iteration: 163, the cost = 0.6835716093601739
# Reached iteration: 164, the cost = 0.6835140734624384
# Reached iteration: 165, the cost = 0.68345654788547
# Reached iteration: 166, the cost = 0.6833990326291896
# Reached iteration: 167, the cost = 0.6833415276935183
# Reached iteration: 168, the cost = 0.683284033078377
# Reached iteration: 169, the cost = 0.6832265487836853
# Reached iteration: 170, the cost = 0.683169074809363
# Reached iteration: 171, the cost = 0.6831116111553288
# Reached iteration: 172, the cost = 0.6830541578215017
# Reached iteration: 173, the cost = 0.6829967148077997
# Reached iteration: 174, the cost = 0.68293928211414
# Reached iteration: 175, the cost = 0.6828818597404407
# Reached iteration: 176, the cost = 0.6828244476866175
# Reached iteration: 177, the cost = 0.6827670459525874
# Reached iteration: 178, the cost = 0.6827096545382662
# Reached iteration: 179, the cost = 0.6826522734435685
# Reached iteration: 180, the cost = 0.6825949026684094
# Reached iteration: 181, the cost = 0.6825375422127032
# Reached iteration: 182, the cost = 0.6824801920763642
# Reached iteration: 183, the cost = 0.6824228522593053
# Reached iteration: 184, the cost = 0.6823655227614396
# Reached iteration: 185, the cost = 0.6823082035826795
# Reached iteration: 186, the cost = 0.6822508947229369
# Reached iteration: 187, the cost = 0.6821935961821234
# Reached iteration: 188, the cost = 0.6821363079601502
# Reached iteration: 189, the cost = 0.6820790300569276
# Reached iteration: 190, the cost = 0.6820217624723657
# Reached iteration: 191, the cost = 0.681964505206374
# Reached iteration: 192, the cost = 0.6819072582588618
# Reached iteration: 193, the cost = 0.6818500216297377
# Reached iteration: 194, the cost = 0.6817927953189101
# Reached iteration: 195, the cost = 0.6817355793262866
# Reached iteration: 196, the cost = 0.6816783736517742
# Reached iteration: 197, the cost = 0.6816211782952799
# Reached iteration: 198, the cost = 0.6815639932567099
# Reached iteration: 199, the cost = 0.68150681853597
# Reached iteration: 200, the cost = 0.6814496541329657
# Reached iteration: 201, the cost = 0.6813925000476014
# Reached iteration: 202, the cost = 0.6813353562797825
# Reached iteration: 203, the cost = 0.681278222829412
# Reached iteration: 204, the cost = 0.6812210996963934
# Reached iteration: 205, the cost = 0.6811639868806304
# Reached iteration: 206, the cost = 0.6811068843820249
# Reached iteration: 207, the cost = 0.6810497922004788
# Reached iteration: 208, the cost = 0.6809927103358945
# Reached iteration: 209, the cost = 0.6809356387881722
# Reached iteration: 210, the cost = 0.6808785775572127
# Reached iteration: 211, the cost = 0.6808215266429168
# Reached iteration: 212, the cost = 0.6807644860451836
# Reached iteration: 213, the cost = 0.6807074557639123
# Reached iteration: 214, the cost = 0.6806504357990018
# Reached iteration: 215, the cost = 0.6805934261503501
# Reached iteration: 216, the cost = 0.6805364268178553
# Reached iteration: 217, the cost = 0.6804794378014146
# Reached iteration: 218, the cost = 0.680422459100925
# Reached iteration: 219, the cost = 0.6803654907162826
# Reached iteration: 220, the cost = 0.6803085326473834
# Reached iteration: 221, the cost = 0.6802515848941226
# Reached iteration: 222, the cost = 0.6801946474563957
# Reached iteration: 223, the cost = 0.6801377203340968
# Reached iteration: 224, the cost = 0.6800808035271197
# Reached iteration: 225, the cost = 0.6800238970353587
# Reached iteration: 226, the cost = 0.679967000858706
# Reached iteration: 227, the cost = 0.6799101149970546
# Reached iteration: 228, the cost = 0.6798532394502965
# Reached iteration: 229, the cost = 0.6797963742183236
# Reached iteration: 230, the cost = 0.6797395193010267
# Reached iteration: 231, the cost = 0.6796826746982967
# Reached iteration: 232, the cost = 0.6796258404100238
# Reached iteration: 233, the cost = 0.6795690164360981
# Reached iteration: 234, the cost = 0.6795122027764083
# Reached iteration: 235, the cost = 0.6794553994308435
# Reached iteration: 236, the cost = 0.6793986063992921
# Reached iteration: 237, the cost = 0.6793418236816419
# Reached iteration: 238, the cost = 0.6792850512777803
# Reached iteration: 239, the cost = 0.6792282891875943
# Reached iteration: 240, the cost = 0.67917153741097
# Reached iteration: 241, the cost = 0.679114795947794
# Reached iteration: 242, the cost = 0.679058064797951
# Reached iteration: 243, the cost = 0.6790013439613268
# Reached iteration: 244, the cost = 0.6789446334378059
# Reached iteration: 245, the cost = 0.6788879332272718
# Reached iteration: 246, the cost = 0.6788312433296086
# Reached iteration: 247, the cost = 0.6787745637446995
# Reached iteration: 248, the cost = 0.6787178944724269
# Reached iteration: 249, the cost = 0.6786612355126732
# Reached iteration: 250, the cost = 0.6786045868653203
# Reached iteration: 251, the cost = 0.6785479485302489
# Reached iteration: 252, the cost = 0.6784913205073404
# Reached iteration: 253, the cost = 0.6784347027964748
# Reached iteration: 254, the cost = 0.6783780953975318
# Reached iteration: 255, the cost = 0.6783214983103912
# Reached iteration: 256, the cost = 0.6782649115349316
# Reached iteration: 257, the cost = 0.6782083350710317
# Reached iteration: 258, the cost = 0.6781517689185693
# Reached iteration: 259, the cost = 0.678095213077422
# Reached iteration: 260, the cost = 0.6780386675474667
# Reached iteration: 261, the cost = 0.6779821323285801
# Reached iteration: 262, the cost = 0.6779256074206379
# Reached iteration: 263, the cost = 0.6778690928235162
# Reached iteration: 264, the cost = 0.6778125885370898
# Reached iteration: 265, the cost = 0.6777560945612336
# Reached iteration: 266, the cost = 0.6776996108958215
# Reached iteration: 267, the cost = 0.6776431375407278
# Reached iteration: 268, the cost = 0.6775866744958251
# Reached iteration: 269, the cost = 0.6775302217609865
# Reached iteration: 270, the cost = 0.6774737793360844
# Reached iteration: 271, the cost = 0.6774173472209907
# Reached iteration: 272, the cost = 0.6773609254155762
# Reached iteration: 273, the cost = 0.6773045139197126
# Reached iteration: 274, the cost = 0.6772481127332697
# Reached iteration: 275, the cost = 0.6771917218561176
# Reached iteration: 276, the cost = 0.6771353412881262
# Reached iteration: 277, the cost = 0.677078971029164
# Reached iteration: 278, the cost = 0.6770226110791001
# Reached iteration: 279, the cost = 0.6769662614378019
# Reached iteration: 280, the cost = 0.6769099221051372
# Reached iteration: 281, the cost = 0.6768535930809736
# Reached iteration: 282, the cost = 0.6767972743651773
# Reached iteration: 283, the cost = 0.6767409659576148
# Reached iteration: 284, the cost = 0.6766846678581518
# Reached iteration: 285, the cost = 0.6766283800666533
# Reached iteration: 286, the cost = 0.6765721025829841
# Reached iteration: 287, the cost = 0.6765158354070085
# Reached iteration: 288, the cost = 0.6764595785385907
# Reached iteration: 289, the cost = 0.676403331977594
# Reached iteration: 290, the cost = 0.676347095723881
# Reached iteration: 291, the cost = 0.6762908697773142
# Reached iteration: 292, the cost = 0.6762346541377556
# Reached iteration: 293, the cost = 0.6761784488050668
# Reached iteration: 294, the cost = 0.6761222537791091
# Reached iteration: 295, the cost = 0.6760660690597424
# Reached iteration: 296, the cost = 0.6760098946468273
# Reached iteration: 297, the cost = 0.675953730540223
# Reached iteration: 298, the cost = 0.6758975767397888
# Reached iteration: 299, the cost = 0.6758414332453837
# Reached iteration: 300, the cost = 0.6757853000568657
# Reached iteration: 301, the cost = 0.6757291771740925
# Reached iteration: 302, the cost = 0.6756730645969211
# Reached iteration: 303, the cost = 0.6756169623252086
# Reached iteration: 304, the cost = 0.6755608703588114
# Reached iteration: 305, the cost = 0.6755047886975852
# Reached iteration: 306, the cost = 0.6754487173413852
# Reached iteration: 307, the cost = 0.6753926562900666
# Reached iteration: 308, the cost = 0.6753366055434838
# Reached iteration: 309, the cost = 0.6752805651014907
# Reached iteration: 310, the cost = 0.6752245349639412
# Reached iteration: 311, the cost = 0.6751685151306878
# Reached iteration: 312, the cost = 0.6751125056015832
# Reached iteration: 313, the cost = 0.6750565063764796
# Reached iteration: 314, the cost = 0.6750005174552286
# Reached iteration: 315, the cost = 0.6749445388376814
# Reached iteration: 316, the cost = 0.6748885705236884
# Reached iteration: 317, the cost = 0.6748326125131
# Reached iteration: 318, the cost = 0.6747766648057665
# Reached iteration: 319, the cost = 0.6747207274015363
# Reached iteration: 320, the cost = 0.6746648003002588
# Reached iteration: 321, the cost = 0.674608883501782
# Reached iteration: 322, the cost = 0.6745529770059543
# Reached iteration: 323, the cost = 0.6744970808126226
# Reached iteration: 324, the cost = 0.6744411949216337
# Reached iteration: 325, the cost = 0.6743853193328346
# Reached iteration: 326, the cost = 0.6743294540460713
# Reached iteration: 327, the cost = 0.6742735990611886
# Reached iteration: 328, the cost = 0.6742177543780322
# Reached iteration: 329, the cost = 0.6741619199964467
# Reached iteration: 330, the cost = 0.674106095916276
# Reached iteration: 331, the cost = 0.6740502821373637
# Reached iteration: 332, the cost = 0.6739944786595532
# Reached iteration: 333, the cost = 0.6739386854826873
# Reached iteration: 334, the cost = 0.673882902606608
# Reached iteration: 335, the cost = 0.673827130031157
# Reached iteration: 336, the cost = 0.673771367756176
# Reached iteration: 337, the cost = 0.6737156157815056
# Reached iteration: 338, the cost = 0.6736598741069862
# Reached iteration: 339, the cost = 0.6736041427324577
# Reached iteration: 340, the cost = 0.6735484216577595
# Reached iteration: 341, the cost = 0.6734927108827308
# Reached iteration: 342, the cost = 0.6734370104072099
# Reached iteration: 343, the cost = 0.6733813202310347
# Reached iteration: 344, the cost = 0.6733256403540431
# Reached iteration: 345, the cost = 0.6732699707760719
# Reached iteration: 346, the cost = 0.673214311496958
# Reached iteration: 347, the cost = 0.6731586625165373
# Reached iteration: 348, the cost = 0.6731030238346456
# Reached iteration: 349, the cost = 0.6730473954511186
# Reached iteration: 350, the cost = 0.6729917773657901
# Reached iteration: 351, the cost = 0.6729361695784951
# Reached iteration: 352, the cost = 0.6728805720890673
# Reached iteration: 353, the cost = 0.67282498489734
# Reached iteration: 354, the cost = 0.6727694080031458
# Reached iteration: 355, the cost = 0.6727138414063177
# Reached iteration: 356, the cost = 0.6726582851066875
# Reached iteration: 357, the cost = 0.6726027391040862
# Reached iteration: 358, the cost = 0.6725472033983451
# Reached iteration: 359, the cost = 0.6724916779892951
# Reached iteration: 360, the cost = 0.6724361628767658
# Reached iteration: 361, the cost = 0.672380658060587
# Reached iteration: 362, the cost = 0.6723251635405878
# Reached iteration: 363, the cost = 0.6722696793165972
# Reached iteration: 364, the cost = 0.6722142053884427
# Reached iteration: 365, the cost = 0.672158741755953
# Reached iteration: 366, the cost = 0.6721032884189546
# Reached iteration: 367, the cost = 0.6720478453772747
# Reached iteration: 368, the cost = 0.6719924126307393
# Reached iteration: 369, the cost = 0.6719369901791745
# Reached iteration: 370, the cost = 0.671881578022406
# Reached iteration: 371, the cost = 0.6718261761602582
# Reached iteration: 372, the cost = 0.671770784592556
# Reached iteration: 373, the cost = 0.6717154033191233
# Reached iteration: 374, the cost = 0.6716600323397833
# Reached iteration: 375, the cost = 0.6716046716543597
# Reached iteration: 376, the cost = 0.6715493212626745
# Reached iteration: 377, the cost = 0.6714939811645503
# Reached iteration: 378, the cost = 0.6714386513598083
# Reached iteration: 379, the cost = 0.6713833318482704
# Reached iteration: 380, the cost = 0.6713280226297565
# Reached iteration: 381, the cost = 0.6712727237040876
# Reached iteration: 382, the cost = 0.6712174350710833
# Reached iteration: 383, the cost = 0.6711621567305628
# Reached iteration: 384, the cost = 0.6711068886823449
# Reached iteration: 385, the cost = 0.6710516309262481
# Reached iteration: 386, the cost = 0.6709963834620907
# Reached iteration: 387, the cost = 0.6709411462896896
# Reached iteration: 388, the cost = 0.670885919408862
# Reached iteration: 389, the cost = 0.670830702819425
# Reached iteration: 390, the cost = 0.6707754965211937
# Reached iteration: 391, the cost = 0.6707203005139846
# Reached iteration: 392, the cost = 0.6706651147976121
# Reached iteration: 393, the cost = 0.6706099393718915
# Reached iteration: 394, the cost = 0.6705547742366366
# Reached iteration: 395, the cost = 0.6704996193916614
# Reached iteration: 396, the cost = 0.6704444748367792
# Reached iteration: 397, the cost = 0.6703893405718025
# Reached iteration: 398, the cost = 0.6703342165965438
# Reached iteration: 399, the cost = 0.6702791029108154
# Reached iteration: 400, the cost = 0.6702239995144279
# Reached iteration: 401, the cost = 0.6701689064071931
# Reached iteration: 402, the cost = 0.6701138235889211
# Reached iteration: 403, the cost = 0.6700587510594218
# Reached iteration: 404, the cost = 0.6700036888185048
# Reached iteration: 405, the cost = 0.6699486368659793
# Reached iteration: 406, the cost = 0.6698935952016539
# Reached iteration: 407, the cost = 0.6698385638253369
# Reached iteration: 408, the cost = 0.6697835427368358
# Reached iteration: 409, the cost = 0.6697285319359578
# Reached iteration: 410, the cost = 0.6696735314225097
# Reached iteration: 411, the cost = 0.669618541196298
# Reached iteration: 412, the cost = 0.6695635612571286
# Reached iteration: 413, the cost = 0.6695085916048064
# Reached iteration: 414, the cost = 0.6694536322391366
# Reached iteration: 415, the cost = 0.6693986831599236
# Reached iteration: 416, the cost = 0.6693437443669713
# Reached iteration: 417, the cost = 0.6692888158600835
# Reached iteration: 418, the cost = 0.6692338976390626
# Reached iteration: 419, the cost = 0.669178989703712
# Reached iteration: 420, the cost = 0.6691240920538334
# Reached iteration: 421, the cost = 0.6690692046892284
# Reached iteration: 422, the cost = 0.6690143276096984
# Reached iteration: 423, the cost = 0.6689594608150438
# Reached iteration: 424, the cost = 0.6689046043050653
# Reached iteration: 425, the cost = 0.6688497580795622
# Reached iteration: 426, the cost = 0.6687949221383341
# Reached iteration: 427, the cost = 0.66874009648118
# Reached iteration: 428, the cost = 0.6686852811078979
# Reached iteration: 429, the cost = 0.6686304760182862
# Reached iteration: 430, the cost = 0.6685756812121421
# Reached iteration: 431, the cost = 0.6685208966892625
# Reached iteration: 432, the cost = 0.6684661224494443
# Reached iteration: 433, the cost = 0.6684113584924833
# Reached iteration: 434, the cost = 0.668356604818175
# Reached iteration: 435, the cost = 0.6683018614263151
# Reached iteration: 436, the cost = 0.6682471283166976
# Reached iteration: 437, the cost = 0.6681924054891172
# Reached iteration: 438, the cost = 0.6681376929433676
# Reached iteration: 439, the cost = 0.6680829906792418
# Reached iteration: 440, the cost = 0.6680282986965329
# Reached iteration: 441, the cost = 0.6679736169950334
# Reached iteration: 442, the cost = 0.667918945574535
# Reached iteration: 443, the cost = 0.6678642844348288
# Reached iteration: 444, the cost = 0.6678096335757064
# Reached iteration: 445, the cost = 0.6677549929969581
# Reached iteration: 446, the cost = 0.6677003626983737
# Reached iteration: 447, the cost = 0.6676457426797433
# Reached iteration: 448, the cost = 0.6675911329408555
# Reached iteration: 449, the cost = 0.6675365334814992
# Reached iteration: 450, the cost = 0.6674819443014627
# Reached iteration: 451, the cost = 0.6674273654005333
# Reached iteration: 452, the cost = 0.667372796778499
# Reached iteration: 453, the cost = 0.6673182384351458
# Reached iteration: 454, the cost = 0.6672636903702605
# Reached iteration: 455, the cost = 0.6672091525836291
# Reached iteration: 456, the cost = 0.6671546250750368
# Reached iteration: 457, the cost = 0.6671001078442685
# Reached iteration: 458, the cost = 0.6670456008911089
# Reached iteration: 459, the cost = 0.6669911042153419
# Reached iteration: 460, the cost = 0.6669366178167511
# Reached iteration: 461, the cost = 0.6668821416951195
# Reached iteration: 462, the cost = 0.6668276758502301
# Reached iteration: 463, the cost = 0.6667732202818644
# Reached iteration: 464, the cost = 0.6667187749898049
# Reached iteration: 465, the cost = 0.6666643399738326
# Reached iteration: 466, the cost = 0.6666099152337279
# Reached iteration: 467, the cost = 0.6665555007692716
# Reached iteration: 468, the cost = 0.6665010965802433
# Reached iteration: 469, the cost = 0.6664467026664227
# Reached iteration: 470, the cost = 0.6663923190275881
# Reached iteration: 471, the cost = 0.666337945663519
# Reached iteration: 472, the cost = 0.6662835825739926
# Reached iteration: 473, the cost = 0.6662292297587868
# Reached iteration: 474, the cost = 0.6661748872176787
# Reached iteration: 475, the cost = 0.6661205549504448
# Reached iteration: 476, the cost = 0.6660662329568612
# Reached iteration: 477, the cost = 0.666011921236704
# Reached iteration: 478, the cost = 0.665957619789748
# Reached iteration: 479, the cost = 0.6659033286157683
# Reached iteration: 480, the cost = 0.6658490477145389
# Reached iteration: 481, the cost = 0.6657947770858342
# Reached iteration: 482, the cost = 0.6657405167294271
# Reached iteration: 483, the cost = 0.665686266645091
# Reached iteration: 484, the cost = 0.6656320268325979
# Reached iteration: 485, the cost = 0.66557779729172
# Reached iteration: 486, the cost = 0.6655235780222291
# Reached iteration: 487, the cost = 0.6654693690238961
# Reached iteration: 488, the cost = 0.6654151702964914
# Reached iteration: 489, the cost = 0.6653609818397856
# Reached iteration: 490, the cost = 0.6653068036535482
# Reached iteration: 491, the cost = 0.6652526357375486
# Reached iteration: 492, the cost = 0.6651984780915554
# Reached iteration: 493, the cost = 0.6651443307153371
# Reached iteration: 494, the cost = 0.6650901936086614
# Reached iteration: 495, the cost = 0.665036066771296
# Reached iteration: 496, the cost = 0.6649819502030073
# Reached iteration: 497, the cost = 0.6649278439035626
# Reached iteration: 498, the cost = 0.6648737478727272
# Reached iteration: 499, the cost = 0.664819662110267
# Reached iteration: 500, the cost = 0.6647655866159471
# Reached iteration: 501, the cost = 0.664711521389532
# Reached iteration: 502, the cost = 0.6646574664307864
# Reached iteration: 503, the cost = 0.6646034217394734
# Reached iteration: 504, the cost = 0.6645493873153564
# Reached iteration: 505, the cost = 0.6644953631581981
# Reached iteration: 506, the cost = 0.6644413492677614
# Reached iteration: 507, the cost = 0.664387345643808
# Reached iteration: 508, the cost = 0.664333352286099
# Reached iteration: 509, the cost = 0.6642793691943956
# Reached iteration: 510, the cost = 0.6642253963684582
# Reached iteration: 511, the cost = 0.6641714338080472
# Reached iteration: 512, the cost = 0.6641174815129216
# Reached iteration: 513, the cost = 0.664063539482841
# Reached iteration: 514, the cost = 0.6640096077175638
# Reached iteration: 515, the cost = 0.6639556862168484
# Reached iteration: 516, the cost = 0.6639017749804524
# Reached iteration: 517, the cost = 0.6638478740081333
# Reached iteration: 518, the cost = 0.6637939832996476
# Reached iteration: 519, the cost = 0.663740102854752
# Reached iteration: 520, the cost = 0.6636862326732024
# Reached iteration: 521, the cost = 0.663632372754754
# Reached iteration: 522, the cost = 0.663578523099162
# Reached iteration: 523, the cost = 0.6635246837061809
# Reached iteration: 524, the cost = 0.6634708545755649
# Reached iteration: 525, the cost = 0.6634170357070673
# Reached iteration: 526, the cost = 0.6633632271004416
# Reached iteration: 527, the cost = 0.6633094287554404
# Reached iteration: 528, the cost = 0.6632556406718157
# Reached iteration: 529, the cost = 0.6632018628493197
# Reached iteration: 530, the cost = 0.6631480952877032
# Reached iteration: 531, the cost = 0.6630943379867177
# Reached iteration: 532, the cost = 0.6630405909461132
# Reached iteration: 533, the cost = 0.6629868541656398
# Reached iteration: 534, the cost = 0.662933127645047
# Reached iteration: 535, the cost = 0.6628794113840835
# Reached iteration: 536, the cost = 0.6628257053824983
# Reached iteration: 537, the cost = 0.6627720096400394
# Reached iteration: 538, the cost = 0.6627183241564545
# Reached iteration: 539, the cost = 0.6626646489314908
# Reached iteration: 540, the cost = 0.6626109839648947
# Reached iteration: 541, the cost = 0.6625573292564133
# Reached iteration: 542, the cost = 0.6625036848057912
# Reached iteration: 543, the cost = 0.6624500506127748
# Reached iteration: 544, the cost = 0.662396426677109
# Reached iteration: 545, the cost = 0.6623428129985376
# Reached iteration: 546, the cost = 0.6622892095768051
# Reached iteration: 547, the cost = 0.6622356164116547
# Reached iteration: 548, the cost = 0.6621820335028301
# Reached iteration: 549, the cost = 0.662128460850073
# Reached iteration: 550, the cost = 0.6620748984531264
# Reached iteration: 551, the cost = 0.6620213463117315
# Reached iteration: 552, the cost = 0.6619678044256299
# Reached iteration: 553, the cost = 0.661914272794562
# Reached iteration: 554, the cost = 0.6618607514182687
# Reached iteration: 555, the cost = 0.6618072402964896
# Reached iteration: 556, the cost = 0.6617537394289638
# Reached iteration: 557, the cost = 0.6617002488154308
# Reached iteration: 558, the cost = 0.6616467684556285
# Reached iteration: 559, the cost = 0.6615932983492959
# Reached iteration: 560, the cost = 0.6615398384961696
# Reached iteration: 561, the cost = 0.6614863888959873
# Reached iteration: 562, the cost = 0.6614329495484857
# Reached iteration: 563, the cost = 0.6613795204534009
# Reached iteration: 564, the cost = 0.6613261016104685
# Reached iteration: 565, the cost = 0.661272693019424
# Reached iteration: 566, the cost = 0.6612192946800025
# Reached iteration: 567, the cost = 0.6611659065919381
# Reached iteration: 568, the cost = 0.6611125287549646
# Reached iteration: 569, the cost = 0.6610591611688159
# Reached iteration: 570, the cost = 0.6610058038332249
# Reached iteration: 571, the cost = 0.6609524567479241
# Reached iteration: 572, the cost = 0.6608991199126456
# Reached iteration: 573, the cost = 0.6608457933271208
# Reached iteration: 574, the cost = 0.6607924769910818
# Reached iteration: 575, the cost = 0.6607391709042585
# Reached iteration: 576, the cost = 0.6606858750663817
# Reached iteration: 577, the cost = 0.6606325894771808
# Reached iteration: 578, the cost = 0.6605793141363858
# Reached iteration: 579, the cost = 0.6605260490437251
# Reached iteration: 580, the cost = 0.6604727941989273
# Reached iteration: 581, the cost = 0.6604195496017207
# Reached iteration: 582, the cost = 0.6603663152518325
# Reached iteration: 583, the cost = 0.6603130911489901
# Reached iteration: 584, the cost = 0.6602598772929199
# Reached iteration: 585, the cost = 0.6602066736833484
# Reached iteration: 586, the cost = 0.6601534803200011
# Reached iteration: 587, the cost = 0.6601002972026035
# Reached iteration: 588, the cost = 0.6600471243308803
# Reached iteration: 589, the cost = 0.6599939617045558
# Reached iteration: 590, the cost = 0.6599408093233544
# Reached iteration: 591, the cost = 0.6598876671869991
# Reached iteration: 592, the cost = 0.6598345352952129
# Reached iteration: 593, the cost = 0.6597814136477186
# Reached iteration: 594, the cost = 0.6597283022442383
# Reached iteration: 595, the cost = 0.6596752010844938
# Reached iteration: 596, the cost = 0.6596221101682059
# Reached iteration: 597, the cost = 0.6595690294950957
# Reached iteration: 598, the cost = 0.6595159590648834
# Reached iteration: 599, the cost = 0.6594628988772885
# Reached iteration: 600, the cost = 0.6594098489320311
# Reached iteration: 601, the cost = 0.6593568092288296
# Reached iteration: 602, the cost = 0.6593037797674026
# Reached iteration: 603, the cost = 0.6592507605474682
# Reached iteration: 604, the cost = 0.659197751568744
# Reached iteration: 605, the cost = 0.6591447528309471
# Reached iteration: 606, the cost = 0.659091764333794
# Reached iteration: 607, the cost = 0.6590387860770011
# Reached iteration: 608, the cost = 0.658985818060284
# Reached iteration: 609, the cost = 0.6589328602833583
# Reached iteration: 610, the cost = 0.6588799127459385
# Reached iteration: 611, the cost = 0.6588269754477394
# Reached iteration: 612, the cost = 0.6587740483884745
# Reached iteration: 613, the cost = 0.6587211315678576
# Reached iteration: 614, the cost = 0.6586682249856017
# Reached iteration: 615, the cost = 0.6586153286414195
# Reached iteration: 616, the cost = 0.6585624425350227
# Reached iteration: 617, the cost = 0.6585095666661235
# Reached iteration: 618, the cost = 0.6584567010344325
# Reached iteration: 619, the cost = 0.6584038456396613
# Reached iteration: 620, the cost = 0.6583510004815198
# Reached iteration: 621, the cost = 0.6582981655597179
# Reached iteration: 622, the cost = 0.658245340873965
# Reached iteration: 623, the cost = 0.6581925264239701
# Reached iteration: 624, the cost = 0.6581397222094414
# Reached iteration: 625, the cost = 0.6580869282300875
# Reached iteration: 626, the cost = 0.658034144485616
# Reached iteration: 627, the cost = 0.6579813709757333
# Reached iteration: 628, the cost = 0.6579286077001473
# Reached iteration: 629, the cost = 0.6578758546585632
# Reached iteration: 630, the cost = 0.6578231118506873
# Reached iteration: 631, the cost = 0.6577703792762248
# Reached iteration: 632, the cost = 0.6577176569348808
# Reached iteration: 633, the cost = 0.6576649448263597
# Reached iteration: 634, the cost = 0.6576122429503656
# Reached iteration: 635, the cost = 0.6575595513066016
# Reached iteration: 636, the cost = 0.6575068698947709
# Reached iteration: 637, the cost = 0.6574541987145766
# Reached iteration: 638, the cost = 0.6574015377657206
# Reached iteration: 639, the cost = 0.6573488870479046
# Reached iteration: 640, the cost = 0.6572962465608301
# Reached iteration: 641, the cost = 0.6572436163041975
# Reached iteration: 642, the cost = 0.6571909962777077
# Reached iteration: 643, the cost = 0.6571383864810606
# Reached iteration: 644, the cost = 0.657085786913955
# Reached iteration: 645, the cost = 0.6570331975760909
# Reached iteration: 646, the cost = 0.6569806184671664
# Reached iteration: 647, the cost = 0.6569280495868796
# Reached iteration: 648, the cost = 0.6568754909349283
# Reached iteration: 649, the cost = 0.6568229425110096
# Reached iteration: 650, the cost = 0.6567704043148206
# Reached iteration: 651, the cost = 0.6567178763460573
# Reached iteration: 652, the cost = 0.6566653586044157
# Reached iteration: 653, the cost = 0.6566128510895913
# Reached iteration: 654, the cost = 0.6565603538012791
# Reached iteration: 655, the cost = 0.6565078667391735
# Reached iteration: 656, the cost = 0.6564553899029686
# Reached iteration: 657, the cost = 0.6564029232923582
# Reached iteration: 658, the cost = 0.6563504669070355
# Reached iteration: 659, the cost = 0.6562980207466929
# Reached iteration: 660, the cost = 0.656245584811023
# Reached iteration: 661, the cost = 0.6561931590997174
# Reached iteration: 662, the cost = 0.6561407436124678
# Reached iteration: 663, the cost = 0.6560883383489651
# Reached iteration: 664, the cost = 0.6560359433088996
# Reached iteration: 665, the cost = 0.6559835584919612
# Reached iteration: 666, the cost = 0.65593118389784
# Reached iteration: 667, the cost = 0.6558788195262245
# Reached iteration: 668, the cost = 0.655826465376804
# Reached iteration: 669, the cost = 0.6557741214492666
# Reached iteration: 670, the cost = 0.6557217877432997
# Reached iteration: 671, the cost = 0.6556694642585912
# Reached iteration: 672, the cost = 0.6556171509948274
# Reached iteration: 673, the cost = 0.6555648479516952
# Reached iteration: 674, the cost = 0.6555125551288807
# Reached iteration: 675, the cost = 0.6554602725260691
# Reached iteration: 676, the cost = 0.6554080001429456
# Reached iteration: 677, the cost = 0.6553557379791951
# Reached iteration: 678, the cost = 0.6553034860345015
# Reached iteration: 679, the cost = 0.6552512443085484
# Reached iteration: 680, the cost = 0.6551990128010199
# Reached iteration: 681, the cost = 0.6551467915115982
# Reached iteration: 682, the cost = 0.6550945804399655
# Reached iteration: 683, the cost = 0.6550423795858045
# Reached iteration: 684, the cost = 0.6549901889487962
# Reached iteration: 685, the cost = 0.6549380085286219
# Reached iteration: 686, the cost = 0.6548858383249622
# Reached iteration: 687, the cost = 0.6548336783374973
# Reached iteration: 688, the cost = 0.6547815285659069
# Reached iteration: 689, the cost = 0.6547293890098701
# Reached iteration: 690, the cost = 0.6546772596690659
# Reached iteration: 691, the cost = 0.654625140543173
# Reached iteration: 692, the cost = 0.6545730316318686
# Reached iteration: 693, the cost = 0.654520932934831
# Reached iteration: 694, the cost = 0.6544688444517365
# Reached iteration: 695, the cost = 0.6544167661822625
# Reached iteration: 696, the cost = 0.6543646981260847
# Reached iteration: 697, the cost = 0.6543126402828786
# Reached iteration: 698, the cost = 0.6542605926523198
# Reached iteration: 699, the cost = 0.6542085552340832
# Reached iteration: 700, the cost = 0.6541565280278429
# Reached iteration: 701, the cost = 0.6541045110332727
# Reached iteration: 702, the cost = 0.6540525042500467
# Reached iteration: 703, the cost = 0.6540005076778374
# Reached iteration: 704, the cost = 0.6539485213163175
# Reached iteration: 705, the cost = 0.6538965451651592
# Reached iteration: 706, the cost = 0.6538445792240342
# Reached iteration: 707, the cost = 0.6537926234926136
# Reached iteration: 708, the cost = 0.6537406779705685
# Reached iteration: 709, the cost = 0.6536887426575687
# Reached iteration: 710, the cost = 0.6536368175532847
# Reached iteration: 711, the cost = 0.653584902657386
# Reached iteration: 712, the cost = 0.653532997969541
# Reached iteration: 713, the cost = 0.6534811034894188
# Reached iteration: 714, the cost = 0.6534292192166871
# Reached iteration: 715, the cost = 0.6533773451510143
# Reached iteration: 716, the cost = 0.6533254812920669
# Reached iteration: 717, the cost = 0.6532736276395121
# Reached iteration: 718, the cost = 0.6532217841930161
# Reached iteration: 719, the cost = 0.6531699509522448
# Reached iteration: 720, the cost = 0.6531181279168637
# Reached iteration: 721, the cost = 0.6530663150865381
# Reached iteration: 722, the cost = 0.653014512460932
# Reached iteration: 723, the cost = 0.6529627200397099
# Reached iteration: 724, the cost = 0.6529109378225353
# Reached iteration: 725, the cost = 0.6528591658090716
# Reached iteration: 726, the cost = 0.6528074039989815
# Reached iteration: 727, the cost = 0.6527556523919275
# Reached iteration: 728, the cost = 0.6527039109875713
# Reached iteration: 729, the cost = 0.6526521797855744
# Reached iteration: 730, the cost = 0.6526004587855979
# Reached iteration: 731, the cost = 0.6525487479873024
# Reached iteration: 732, the cost = 0.6524970473903479
# Reached iteration: 733, the cost = 0.652445356994394
# Reached iteration: 734, the cost = 0.6523936767991002
# Reached iteration: 735, the cost = 0.6523420068041251
# Reached iteration: 736, the cost = 0.6522903470091274
# Reached iteration: 737, the cost = 0.6522386974137645
# Reached iteration: 738, the cost = 0.6521870580176943
# Reached iteration: 739, the cost = 0.6521354288205735
# Reached iteration: 740, the cost = 0.6520838098220588
# Reached iteration: 741, the cost = 0.6520322010218064
# Reached iteration: 742, the cost = 0.6519806024194722
# Reached iteration: 743, the cost = 0.6519290140147109
# Reached iteration: 744, the cost = 0.6518774358071776
# Reached iteration: 745, the cost = 0.6518258677965271
# Reached iteration: 746, the cost = 0.6517743099824125
# Reached iteration: 747, the cost = 0.6517227623644878
# Reached iteration: 748, the cost = 0.6516712249424063
# Reached iteration: 749, the cost = 0.6516196977158198
# Reached iteration: 750, the cost = 0.6515681806843813
# Reached iteration: 751, the cost = 0.6515166738477417
# Reached iteration: 752, the cost = 0.6514651772055529
# Reached iteration: 753, the cost = 0.6514136907574652
# Reached iteration: 754, the cost = 0.6513622145031297
# Reached iteration: 755, the cost = 0.6513107484421957
# Reached iteration: 756, the cost = 0.6512592925743133
# Reached iteration: 757, the cost = 0.6512078468991308
# Reached iteration: 758, the cost = 0.6511564114162974
# Reached iteration: 759, the cost = 0.6511049861254611
# Reached iteration: 760, the cost = 0.6510535710262698
# Reached iteration: 761, the cost = 0.6510021661183707
# Reached iteration: 762, the cost = 0.6509507714014103
# Reached iteration: 763, the cost = 0.6508993868750355
# Reached iteration: 764, the cost = 0.650848012538892
# Reached iteration: 765, the cost = 0.6507966483926254
# Reached iteration: 766, the cost = 0.650745294435881
# Reached iteration: 767, the cost = 0.6506939506683032
# Reached iteration: 768, the cost = 0.650642617089536
# Reached iteration: 769, the cost = 0.6505912936992239
# Reached iteration: 770, the cost = 0.6505399804970096
# Reached iteration: 771, the cost = 0.6504886774825362
# Reached iteration: 772, the cost = 0.650437384655446
# Reached iteration: 773, the cost = 0.6503861020153812
# Reached iteration: 774, the cost = 0.6503348295619832
# Reached iteration: 775, the cost = 0.6502835672948932
# Reached iteration: 776, the cost = 0.6502323152137519
# Reached iteration: 777, the cost = 0.6501810733181997
# Reached iteration: 778, the cost = 0.6501298416078763
# Reached iteration: 779, the cost = 0.650078620082421
# Reached iteration: 780, the cost = 0.6500274087414727
# Reached iteration: 781, the cost = 0.6499762075846699
# Reached iteration: 782, the cost = 0.6499250166116508
# Reached iteration: 783, the cost = 0.6498738358220529
# Reached iteration: 784, the cost = 0.6498226652155136
# Reached iteration: 785, the cost = 0.649771504791669
# Reached iteration: 786, the cost = 0.649720354550156
# Reached iteration: 787, the cost = 0.6496692144906102
# Reached iteration: 788, the cost = 0.6496180846126672
# Reached iteration: 789, the cost = 0.6495669649159618
# Reached iteration: 790, the cost = 0.6495158554001285
# Reached iteration: 791, the cost = 0.6494647560648017
# Reached iteration: 792, the cost = 0.6494136669096148
# Reached iteration: 793, the cost = 0.6493625879342008
# Reached iteration: 794, the cost = 0.6493115191381931
# Reached iteration: 795, the cost = 0.6492604605212234
# Reached iteration: 796, the cost = 0.6492094120829244
# Reached iteration: 797, the cost = 0.6491583738229266
# Reached iteration: 798, the cost = 0.6491073457408618
# Reached iteration: 799, the cost = 0.6490563278363601
# Reached iteration: 800, the cost = 0.6490053201090519
# Reached iteration: 801, the cost = 0.6489543225585669
# Reached iteration: 802, the cost = 0.6489033351845345
# Reached iteration: 803, the cost = 0.6488523579865833
# Reached iteration: 804, the cost = 0.6488013909643416
# Reached iteration: 805, the cost = 0.6487504341174379
# Reached iteration: 806, the cost = 0.6486994874454993
# Reached iteration: 807, the cost = 0.6486485509481529
# Reached iteration: 808, the cost = 0.6485976246250255
# Reached iteration: 809, the cost = 0.6485467084757431
# Reached iteration: 810, the cost = 0.6484958024999318
# Reached iteration: 811, the cost = 0.648444906697217
# Reached iteration: 812, the cost = 0.6483940210672233
# Reached iteration: 813, the cost = 0.6483431456095751
# Reached iteration: 814, the cost = 0.6482922803238966
# Reached iteration: 815, the cost = 0.6482414252098115
# Reached iteration: 816, the cost = 0.6481905802669431
# Reached iteration: 817, the cost = 0.6481397454949136
# Reached iteration: 818, the cost = 0.6480889208933457
# Reached iteration: 819, the cost = 0.6480381064618612
# Reached iteration: 820, the cost = 0.6479873022000814
# Reached iteration: 821, the cost = 0.6479365081076273
# Reached iteration: 822, the cost = 0.6478857241841195
# Reached iteration: 823, the cost = 0.6478349504291783
# Reached iteration: 824, the cost = 0.647784186842423
# Reached iteration: 825, the cost = 0.6477334334234729
# Reached iteration: 826, the cost = 0.6476826901719468
# Reached iteration: 827, the cost = 0.6476319570874637
# Reached iteration: 828, the cost = 0.6475812341696405
# Reached iteration: 829, the cost = 0.6475305214180956
# Reached iteration: 830, the cost = 0.6474798188324457
# Reached iteration: 831, the cost = 0.6474291264123072
# Reached iteration: 832, the cost = 0.6473784441572965
# Reached iteration: 833, the cost = 0.6473277720670295
# Reached iteration: 834, the cost = 0.6472771101411212
# Reached iteration: 835, the cost = 0.6472264583791869
# Reached iteration: 836, the cost = 0.6471758167808406
# Reached iteration: 837, the cost = 0.6471251853456965
# Reached iteration: 838, the cost = 0.6470745640733685
# Reached iteration: 839, the cost = 0.6470239529634694
# Reached iteration: 840, the cost = 0.6469733520156119
# Reached iteration: 841, the cost = 0.6469227612294084
# Reached iteration: 842, the cost = 0.6468721806044707
# Reached iteration: 843, the cost = 0.6468216101404103
# Reached iteration: 844, the cost = 0.6467710498368382
# Reached iteration: 845, the cost = 0.6467204996933649
# Reached iteration: 846, the cost = 0.6466699597096003
# Reached iteration: 847, the cost = 0.6466194298851545
# Reached iteration: 848, the cost = 0.6465689102196365
# Reached iteration: 849, the cost = 0.646518400712655
# Reached iteration: 850, the cost = 0.6464679013638185
# Reached iteration: 851, the cost = 0.6464174121727351
# Reached iteration: 852, the cost = 0.6463669331390122
# Reached iteration: 853, the cost = 0.6463164642622568
# Reached iteration: 854, the cost = 0.6462660055420755
# Reached iteration: 855, the cost = 0.6462155569780746
# Reached iteration: 856, the cost = 0.6461651185698603
# Reached iteration: 857, the cost = 0.646114690317037
# Reached iteration: 858, the cost = 0.6460642722192107
# Reached iteration: 859, the cost = 0.6460138642759852
# Reached iteration: 860, the cost = 0.6459634664869647
# Reached iteration: 861, the cost = 0.6459130788517528
# Reached iteration: 862, the cost = 0.6458627013699528
# Reached iteration: 863, the cost = 0.6458123340411674
# Reached iteration: 864, the cost = 0.6457619768649988
# Reached iteration: 865, the cost = 0.6457116298410494
# Reached iteration: 866, the cost = 0.6456612929689198
# Reached iteration: 867, the cost = 0.6456109662482118
# Reached iteration: 868, the cost = 0.6455606496785257
# Reached iteration: 869, the cost = 0.6455103432594617
# Reached iteration: 870, the cost = 0.6454600469906195
# Reached iteration: 871, the cost = 0.6454097608715984
# Reached iteration: 872, the cost = 0.6453594849019973
# Reached iteration: 873, the cost = 0.6453092190814147
# Reached iteration: 874, the cost = 0.6452589634094484
# Reached iteration: 875, the cost = 0.6452087178856962
# Reached iteration: 876, the cost = 0.6451584825097553
# Reached iteration: 877, the cost = 0.6451082572812225
# Reached iteration: 878, the cost = 0.6450580421996935
# Reached iteration: 879, the cost = 0.6450078372647648
# Reached iteration: 880, the cost = 0.6449576424760315
# Reached iteration: 881, the cost = 0.6449074578330888
# Reached iteration: 882, the cost = 0.6448572833355314
# Reached iteration: 883, the cost = 0.6448071189829528
# Reached iteration: 884, the cost = 0.6447569647749473
# Reached iteration: 885, the cost = 0.6447068207111081
# Reached iteration: 886, the cost = 0.6446566867910278
# Reached iteration: 887, the cost = 0.6446065630142991
# Reached iteration: 888, the cost = 0.6445564493805138
# Reached iteration: 889, the cost = 0.6445063458892636
# Reached iteration: 890, the cost = 0.6444562525401395
# Reached iteration: 891, the cost = 0.6444061693327325
# ...
# Reached iteration: 1711, the cost = 0.6067061957424281
# Reached iteration: 1712, the cost = 0.6066642632061672
# Reached iteration: 1713, the cost = 0.6066223403408216
# Reached iteration: 1714, the cost = 0.6065804271456705
# Reached iteration: 1715, the cost = 0.6065385236199922
# Reached iteration: 1716, the cost = 0.6064966297630641
# Reached iteration: 1717, the cost = 0.6064547455741642
# Reached iteration: 1718, the cost = 0.6064128710525702
# Reached iteration: 1719, the cost = 0.6063710061975587
# Reached iteration: 1720, the cost = 0.6063291510084065
# Reached iteration: 1721, the cost = 0.6062873054843899
# Reached iteration: 1722, the cost = 0.6062454696247849
# Reached iteration: 1723, the cost = 0.6062036434288675
# Reached iteration: 1724, the cost = 0.6061618268959129
# Reached iteration: 1725, the cost = 0.6061200200251963
# Reached iteration: 1726, the cost = 0.6060782228159927
# Reached iteration: 1727, the cost = 0.6060364352675761
# Reached iteration: 1728, the cost = 0.6059946573792208
# Reached iteration: 1729, the cost = 0.6059528891502006
# Reached iteration: 1730, the cost = 0.6059111305797892
# Reached iteration: 1731, the cost = 0.6058693816672597
# Reached iteration: 1732, the cost = 0.6058276424118849
# Reached iteration: 1733, the cost = 0.6057859128129371
# Reached iteration: 1734, the cost = 0.6057441928696891
# Reached iteration: 1735, the cost = 0.6057024825814122
# Reached iteration: 1736, the cost = 0.6056607819473784
# Reached iteration: 1737, the cost = 0.6056190909668588
# Reached iteration: 1738, the cost = 0.6055774096391243
# Reached iteration: 1739, the cost = 0.6055357379634456
# Reached iteration: 1740, the cost = 0.605494075939093
# Reached iteration: 1741, the cost = 0.6054524235653367
# Reached iteration: 1742, the cost = 0.6054107808414461
# Reached iteration: 1743, the cost = 0.6053691477666905
# Reached iteration: 1744, the cost = 0.6053275243403392
# Reached iteration: 1745, the cost = 0.6052859105616607
# Reached iteration: 1746, the cost = 0.6052443064299237
# Reached iteration: 1747, the cost = 0.6052027119443958
# Reached iteration: 1748, the cost = 0.6051611271043454
# Reached iteration: 1749, the cost = 0.6051195519090394
# Reached iteration: 1750, the cost = 0.6050779863577455
# Reached iteration: 1751, the cost = 0.6050364304497299
# Reached iteration: 1752, the cost = 0.6049948841842596
# Reached iteration: 1753, the cost = 0.6049533475606006
# Reached iteration: 1754, the cost = 0.6049118205780188
# Reached iteration: 1755, the cost = 0.6048703032357797
# Reached iteration: 1756, the cost = 0.6048287955331486
# Reached iteration: 1757, the cost = 0.6047872974693904
# Reached iteration: 1758, the cost = 0.60474580904377
# Reached iteration: 1759, the cost = 0.6047043302555511
# Reached iteration: 1760, the cost = 0.6046628611039983
# Reached iteration: 1761, the cost = 0.604621401588375
# Reached iteration: 1762, the cost = 0.6045799517079445
# Reached iteration: 1763, the cost = 0.60453851146197
# Reached iteration: 1764, the cost = 0.6044970808497141
# Reached iteration: 1765, the cost = 0.6044556598704394
# Reached iteration: 1766, the cost = 0.6044142485234076
# Reached iteration: 1767, the cost = 0.6043728468078812
# Reached iteration: 1768, the cost = 0.6043314547231209
# Reached iteration: 1769, the cost = 0.6042900722683883
# Reached iteration: 1770, the cost = 0.604248699442944
# Reached iteration: 1771, the cost = 0.6042073362460488
# Reached iteration: 1772, the cost = 0.6041659826769628
# Reached iteration: 1773, the cost = 0.604124638734946
# Reached iteration: 1774, the cost = 0.6040833044192578
# Reached iteration: 1775, the cost = 0.6040419797291577
# Reached iteration: 1776, the cost = 0.6040006646639046
# Reached iteration: 1777, the cost = 0.6039593592227571
# Reached iteration: 1778, the cost = 0.6039180634049736
# Reached iteration: 1779, the cost = 0.6038767772098119
# Reached iteration: 1780, the cost = 0.6038355006365302
# Reached iteration: 1781, the cost = 0.6037942336843856
# Reached iteration: 1782, the cost = 0.6037529763526353
# Reached iteration: 1783, the cost = 0.6037117286405359
# Reached iteration: 1784, the cost = 0.6036704905473441
# Reached iteration: 1785, the cost = 0.6036292620723162
# Reached iteration: 1786, the cost = 0.6035880432147076
# Reached iteration: 1787, the cost = 0.6035468339737744
# Reached iteration: 1788, the cost = 0.6035056343487712
# Reached iteration: 1789, the cost = 0.6034644443389536
# Reached iteration: 1790, the cost = 0.6034232639435756
# Reached iteration: 1791, the cost = 0.6033820931618921
# Reached iteration: 1792, the cost = 0.6033409319931565
# Reached iteration: 1793, the cost = 0.6032997804366229
# Reached iteration: 1794, the cost = 0.6032586384915447
# Reached iteration: 1795, the cost = 0.6032175061571748
# Reached iteration: 1796, the cost = 0.603176383432766
# Reached iteration: 1797, the cost = 0.6031352703175705
# Reached iteration: 1798, the cost = 0.603094166810841
# Reached iteration: 1799, the cost = 0.603053072911829
# Reached iteration: 1800, the cost = 0.6030119886197859
# Reached iteration: 1801, the cost = 0.6029709139339632
# Reached iteration: 1802, the cost = 0.6029298488536114
# Reached iteration: 1803, the cost = 0.6028887933779818
# Reached iteration: 1804, the cost = 0.602847747506324
# Reached iteration: 1805, the cost = 0.6028067112378883
# Reached iteration: 1806, the cost = 0.6027656845719244
# Reached iteration: 1807, the cost = 0.6027246675076815
# Reached iteration: 1808, the cost = 0.6026836600444088
# Reached iteration: 1809, the cost = 0.602642662181355
# Reached iteration: 1810, the cost = 0.6026016739177685
# Reached iteration: 1811, the cost = 0.6025606952528976
# Reached iteration: 1812, the cost = 0.60251972618599
# Reached iteration: 1813, the cost = 0.6024787667162934
# Reached iteration: 1814, the cost = 0.6024378168430549
# Reached iteration: 1815, the cost = 0.6023968765655212
# Reached iteration: 1816, the cost = 0.6023559458829393
# Reached iteration: 1817, the cost = 0.6023150247945553
# Reached iteration: 1818, the cost = 0.6022741132996151
# Reached iteration: 1819, the cost = 0.6022332113973647
# Reached iteration: 1820, the cost = 0.6021923190870493
# Reached iteration: 1821, the cost = 0.6021514363679139
# Reached iteration: 1822, the cost = 0.6021105632392034
# Reached iteration: 1823, the cost = 0.6020696997001622
# Reached iteration: 1824, the cost = 0.6020288457500346
# Reached iteration: 1825, the cost = 0.6019880013880643
# Reached iteration: 1826, the cost = 0.6019471666134949
# Reached iteration: 1827, the cost = 0.6019063414255698
# Reached iteration: 1828, the cost = 0.6018655258235318
# Reached iteration: 1829, the cost = 0.6018247198066234
# Reached iteration: 1830, the cost = 0.6017839233740874
# Reached iteration: 1831, the cost = 0.6017431365251653
# Reached iteration: 1832, the cost = 0.6017023592590993
# Reached iteration: 1833, the cost = 0.6016615915751305
# Reached iteration: 1834, the cost = 0.6016208334725003
# Reached iteration: 1835, the cost = 0.6015800849504491
# Reached iteration: 1836, the cost = 0.601539346008218
# Reached iteration: 1837, the cost = 0.6014986166450469
# Reached iteration: 1838, the cost = 0.6014578968601756
# Reached iteration: 1839, the cost = 0.6014171866528438
# Reached iteration: 1840, the cost = 0.6013764860222912
# Reached iteration: 1841, the cost = 0.6013357949677561
# Reached iteration: 1842, the cost = 0.601295113488478
# Reached iteration: 1843, the cost = 0.6012544415836946
# Reached iteration: 1844, the cost = 0.6012137792526443
# Reached iteration: 1845, the cost = 0.601173126494565
# Reached iteration: 1846, the cost = 0.6011324833086942
# Reached iteration: 1847, the cost = 0.6010918496942689
# Reached iteration: 1848, the cost = 0.6010512256505262
# Reached iteration: 1849, the cost = 0.6010106111767024
# Reached iteration: 1850, the cost = 0.6009700062720343
# Reached iteration: 1851, the cost = 0.6009294109357574
# Reached iteration: 1852, the cost = 0.6008888251671077
# Reached iteration: 1853, the cost = 0.6008482489653205
# Reached iteration: 1854, the cost = 0.6008076823296307
# Reached iteration: 1855, the cost = 0.6007671252592737
# Reached iteration: 1856, the cost = 0.6007265777534834
# Reached iteration: 1857, the cost = 0.6006860398114943
# Reached iteration: 1858, the cost = 0.6006455114325401
# Reached iteration: 1859, the cost = 0.6006049926158546
# Reached iteration: 1860, the cost = 0.6005644833606709
# Reached iteration: 1861, the cost = 0.6005239836662221
# Reached iteration: 1862, the cost = 0.6004834935317409
# Reached iteration: 1863, the cost = 0.6004430129564599
# Reached iteration: 1864, the cost = 0.6004025419396107
# Reached iteration: 1865, the cost = 0.6003620804804257
# Reached iteration: 1866, the cost = 0.6003216285781361
# Reached iteration: 1867, the cost = 0.6002811862319731
# Reached iteration: 1868, the cost = 0.6002407534411677
# Reached iteration: 1869, the cost = 0.6002003302049504
# Reached iteration: 1870, the cost = 0.6001599165225519
# Reached iteration: 1871, the cost = 0.6001195123932016
# Reached iteration: 1872, the cost = 0.6000791178161294
# Reached iteration: 1873, the cost = 0.6000387327905652
# Reached iteration: 1874, the cost = 0.599998357315738
# Reached iteration: 1875, the cost = 0.599957991390876
# Reached iteration: 1876, the cost = 0.5999176350152083
# Reached iteration: 1877, the cost = 0.5998772881879632
# Reached iteration: 1878, the cost = 0.5998369509083683
# Reached iteration: 1879, the cost = 0.5997966231756515
# Reached iteration: 1880, the cost = 0.5997563049890401
# Reached iteration: 1881, the cost = 0.599715996347761
# Reached iteration: 1882, the cost = 0.5996756972510412
# Reached iteration: 1883, the cost = 0.599635407698107
# Reached iteration: 1884, the cost = 0.5995951276881847
# Reached iteration: 1885, the cost = 0.5995548572205001
# Reached iteration: 1886, the cost = 0.5995145962942786
# Reached iteration: 1887, the cost = 0.599474344908746
# Reached iteration: 1888, the cost = 0.5994341030631266
# Reached iteration: 1889, the cost = 0.5993938707566456
# Reached iteration: 1890, the cost = 0.5993536479885273
# Reached iteration: 1891, the cost = 0.5993134347579957
# Reached iteration: 1892, the cost = 0.5992732310642748
# Reached iteration: 1893, the cost = 0.5992330369065878
# Reached iteration: 1894, the cost = 0.5991928522841583
# Reached iteration: 1895, the cost = 0.5991526771962091
# Reached iteration: 1896, the cost = 0.5991125116419627
# Reached iteration: 1897, the cost = 0.5990723556206415
# Reached iteration: 1898, the cost = 0.5990322091314678
# Reached iteration: 1899, the cost = 0.5989920721736628
# Reached iteration: 1900, the cost = 0.5989519447464486
# Reached iteration: 1901, the cost = 0.5989118268490461
# Reached iteration: 1902, the cost = 0.5988717184806762
# Reached iteration: 1903, the cost = 0.5988316196405594
# Reached iteration: 1904, the cost = 0.5987915303279162
# Reached iteration: 1905, the cost = 0.5987514505419663
# Reached iteration: 1906, the cost = 0.5987113802819299
# Reached iteration: 1907, the cost = 0.5986713195470258
# Reached iteration: 1908, the cost = 0.5986312683364737
# Reached iteration: 1909, the cost = 0.598591226649492
# Reached iteration: 1910, the cost = 0.5985511944852996
# Reached iteration: 1911, the cost = 0.5985111718431144
# Reached iteration: 1912, the cost = 0.5984711587221548
# Reached iteration: 1913, the cost = 0.5984311551216382
# Reached iteration: 1914, the cost = 0.598391161040782
# Reached iteration: 1915, the cost = 0.5983511764788032
# Reached iteration: 1916, the cost = 0.5983112014349191
# Reached iteration: 1917, the cost = 0.5982712359083456
# Reached iteration: 1918, the cost = 0.5982312798982993
# Reached iteration: 1919, the cost = 0.5981913334039958
# Reached iteration: 1920, the cost = 0.5981513964246511
# Reached iteration: 1921, the cost = 0.5981114689594805
# Reached iteration: 1922, the cost = 0.5980715510076989
# Reached iteration: 1923, the cost = 0.5980316425685213
# Reached iteration: 1924, the cost = 0.5979917436411618
# Reached iteration: 1925, the cost = 0.597951854224835
# Reached iteration: 1926, the cost = 0.5979119743187549
# Reached iteration: 1927, the cost = 0.5978721039221345
# Reached iteration: 1928, the cost = 0.5978322430341878
# Reached iteration: 1929, the cost = 0.5977923916541276
# Reached iteration: 1930, the cost = 0.5977525497811665
# Reached iteration: 1931, the cost = 0.597712717414517
# Reached iteration: 1932, the cost = 0.5976728945533918
# Reached iteration: 1933, the cost = 0.597633081197002
# Reached iteration: 1934, the cost = 0.5975932773445599
# Reached iteration: 1935, the cost = 0.5975534829952763
# Reached iteration: 1936, the cost = 0.5975136981483626
# Reached iteration: 1937, the cost = 0.5974739228030294
# Reached iteration: 1938, the cost = 0.5974341569584872
# Reached iteration: 1939, the cost = 0.597394400613946
# Reached iteration: 1940, the cost = 0.5973546537686159
# Reached iteration: 1941, the cost = 0.5973149164217065
# Reached iteration: 1942, the cost = 0.5972751885724271
# Reached iteration: 1943, the cost = 0.5972354702199866
# Reached iteration: 1944, the cost = 0.5971957613635941
# Reached iteration: 1945, the cost = 0.5971560620024574
# Reached iteration: 1946, the cost = 0.5971163721357854
# Reached iteration: 1947, the cost = 0.5970766917627855
# Reached iteration: 1948, the cost = 0.5970370208826655
# Reached iteration: 1949, the cost = 0.5969973594946327
# Reached iteration: 1950, the cost = 0.5969577075978941
# Reached iteration: 1951, the cost = 0.5969180651916566
# Reached iteration: 1952, the cost = 0.5968784322751264
# Reached iteration: 1953, the cost = 0.59683880884751
# Reached iteration: 1954, the cost = 0.5967991949080129
# Reached iteration: 1955, the cost = 0.5967595904558409
# Reached iteration: 1956, the cost = 0.5967199954901995
# Reached iteration: 1957, the cost = 0.5966804100102937
# Reached iteration: 1958, the cost = 0.5966408340153281
# Reached iteration: 1959, the cost = 0.5966012675045071
# Reached iteration: 1960, the cost = 0.5965617104770352
# Reached iteration: 1961, the cost = 0.5965221629321161
# Reached iteration: 1962, the cost = 0.5964826248689535
# Reached iteration: 1963, the cost = 0.5964430962867506
# Reached iteration: 1964, the cost = 0.5964035771847109
# Reached iteration: 1965, the cost = 0.5963640675620365
# Reached iteration: 1966, the cost = 0.5963245674179306
# Reached iteration: 1967, the cost = 0.596285076751595
# Reached iteration: 1968, the cost = 0.5962455955622317
# Reached iteration: 1969, the cost = 0.5962061238490425
# Reached iteration: 1970, the cost = 0.5961666616112287
# Reached iteration: 1971, the cost = 0.5961272088479911
# Reached iteration: 1972, the cost = 0.5960877655585309
# Reached iteration: 1973, the cost = 0.5960483317420486
# Reached iteration: 1974, the cost = 0.5960089073977443
# Reached iteration: 1975, the cost = 0.5959694925248181
# Reached iteration: 1976, the cost = 0.5959300871224695
# Reached iteration: 1977, the cost = 0.595890691189898
# Reached iteration: 1978, the cost = 0.5958513047263027
# Reached iteration: 1979, the cost = 0.5958119277308825
# Reached iteration: 1980, the cost = 0.5957725602028361
# Reached iteration: 1981, the cost = 0.5957332021413615
# Reached iteration: 1982, the cost = 0.5956938535456571
# Reached iteration: 1983, the cost = 0.5956545144149199
# Reached iteration: 1984, the cost = 0.5956151847483482
# Reached iteration: 1985, the cost = 0.5955758645451387
# Reached iteration: 1986, the cost = 0.5955365538044884
# Reached iteration: 1987, the cost = 0.5954972525255939
# Reached iteration: 1988, the cost = 0.5954579607076513
# Reached iteration: 1989, the cost = 0.5954186783498572
# Reached iteration: 1990, the cost = 0.595379405451407
# Reached iteration: 1991, the cost = 0.5953401420114962
# Reached iteration: 1992, the cost = 0.5953008880293201
# Reached iteration: 1993, the cost = 0.5952616435040736
# Reached iteration: 1994, the cost = 0.5952224084349513
# Reached iteration: 1995, the cost = 0.5951831828211479
# Reached iteration: 1996, the cost = 0.5951439666618571
# Reached iteration: 1997, the cost = 0.595104759956273
# Reached iteration: 1998, the cost = 0.595065562703589
# Reached iteration: 1999, the cost = 0.5950263749029986
# Reached iteration: 2000, the cost = 0.5949871965536945
#
#
# Parameters have been trained!

# %%
#Explore the trained parameters
theta
# Out:
# array([-0.2851425 ,  0.33266625,  0.21260625])

# %% [markdown]
# # Make Prediction

# %%
#Lets make prediction, in this case we wil make predictions one of the training examples 
print("The Ground Truth: {0}".format(y[0]))
prediction = pred(X[0], theta)
# Out:
# The Ground Truth: 0
# The output: 0.303557327759583
#
# Result: The user didn't purchase the product

# %% [markdown]
# # Congratulations!
